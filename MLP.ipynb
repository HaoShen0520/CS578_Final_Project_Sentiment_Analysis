# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import string

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Hao
# [nltk_data]     Shen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Hao
# [nltk_data]     Shen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Hao
# [nltk_data]     Shen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_file = 'data/Sentiment.csv'
data = pd.read_csv(data_file)
data = data[['text', 'sentiment']]

# %%
stop_words = set(stopwords.words('english'))
wordnet_lemmatizer = WordNetLemmatizer()
porter_stemmer = PorterStemmer()

# %%
def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
def preprocess_text(text):
    text = re.sub(r'http\S+|www\S+', 'url', text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+', 'email', text)

    # Remove emojis
    text = remove_emojis(text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenize
    tokens = nltk.word_tokenize(text.lower())

    # Lemmatize
    tokens = [wordnet_lemmatizer.lemmatize(token) for token in tokens]

    # Remove stopwords
    tokens = [token for token in tokens if token not in stop_words]

    # Stemming
    tokens = [porter_stemmer.stem(token) for token in tokens]

    return ' '.join(tokens)

# %%
cleaned_text = []

for i, text in enumerate(data['text']):
    cur = preprocess_text(text)
    cleaned_text.append(cur)

data['text'] = cleaned_text

# %%
train_data, temp_data = train_test_split(data, test_size=0.1, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# %%
vectorizer = CountVectorizer(stop_words='english', max_features=2000)

# %%
X_train = vectorizer.fit_transform(train_data['text']).toarray()
X_test = vectorizer.transform(test_data['text']).toarray()
X_val = vectorizer.transform(val_data['text']).toarray()

# %%
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data['sentiment'])
y_test = label_encoder.transform(test_data['sentiment'])
y_val = label_encoder.transform(val_data['sentiment'])

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.int64)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.int64)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.int64)

# %%
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, dropout_rate=0.5):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
hidden_size = 128
num_epochs = 100
learning_rate = 0.001
patience = 10
stop_counter = 0
best_val_loss = np.inf

input_size = X_train.shape[1]
num_classes = len(np.unique(y_train))

model = MLP(input_size, hidden_size, num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
train_f1_scores, val_f1_scores = [], []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_correct, train_total = 0, 0
    for inputs, labels in train_dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        train_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_losses.append(train_loss / len(train_dataloader))
    train_accuracy = train_correct / train_total * 100
    train_accuracies.append(train_accuracy)
    train_f1 = f1_score(y_train_tensor, model(X_train_tensor).argmax(dim=1), average='weighted')
    train_f1_scores.append(train_f1)

    model.eval()
    val_loss = 0.0
    val_correct, val_total = 0, 0
    with torch.no_grad():
        for inputs, labels in val_dataloader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_losses.append(val_loss / len(val_dataloader))
    val_accuracy = val_correct / val_total * 100
    val_accuracies.append(val_accuracy)
    val_f1 = f1_score(y_val_tensor, model(X_val_tensor).argmax(dim=1), average='weighted')
    val_f1_scores.append(val_f1)

    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracy:.2f}%, Train F1: {train_f1:.4f}, '
          f'Val Loss: {val_losses[-1]:.4f}, Val Accuracy: {val_accuracy:.2f}%, Val F1: {val_f1:.4f}')

    # if val_losses[-1] < best_val_loss:
    #     best_val_loss = val_losses[-1]
    #     stop_counter = 0
    #     torch.save(model.state_dict(), 'best_model.pt')
    # else:
    #     stop_counter += 1
    #     if stop_counter >= patience:
    #         print("Early stopping triggered.")
    #         break

# model.load_state_dict(torch.load('best_model.pt'))

model.eval()
test_loss = 0.0
test_correct, test_total = 0, 0
with torch.no_grad():
    for inputs, labels in val_dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = test_correct / test_total * 100
test_f1 = f1_score(y_val_tensor, model(X_val_tensor).argmax(dim=1), average='weighted')

print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%, Test F1: {test_f1:.4f}')
# Out:
# Epoch [1/100], Train Loss: 0.8111, Train Accuracy: 65.22%, Train F1: 0.6884, Val Loss: 0.7602, Val Accuracy: 68.30%, Val F1: 0.6524
# Epoch [2/100], Train Loss: 0.6789, Train Accuracy: 71.09%, Train F1: 0.7273, Val Loss: 0.7527, Val Accuracy: 68.01%, Val F1: 0.6535
# Epoch [3/100], Train Loss: 0.6251, Train Accuracy: 73.62%, Train F1: 0.7537, Val Loss: 0.7582, Val Accuracy: 68.59%, Val F1: 0.6642
# Epoch [4/100], Train Loss: 0.5923, Train Accuracy: 74.85%, Train F1: 0.7749, Val Loss: 0.7629, Val Accuracy: 69.74%, Val F1: 0.6789
# Epoch [5/100], Train Loss: 0.5654, Train Accuracy: 76.40%, Train F1: 0.7895, Val Loss: 0.7779, Val Accuracy: 68.44%, Val F1: 0.6710
# Epoch [6/100], Train Loss: 0.5364, Train Accuracy: 77.59%, Train F1: 0.7979, Val Loss: 0.7994, Val Accuracy: 68.30%, Val F1: 0.6652
# Epoch [7/100], Train Loss: 0.5115, Train Accuracy: 78.83%, Train F1: 0.8158, Val Loss: 0.8081, Val Accuracy: 68.88%, Val F1: 0.6749
# Epoch [8/100], Train Loss: 0.4864, Train Accuracy: 80.05%, Train F1: 0.8220, Val Loss: 0.8390, Val Accuracy: 68.59%, Val F1: 0.6706
# Epoch [9/100], Train Loss: 0.4613, Train Accuracy: 81.29%, Train F1: 0.8419, Val Loss: 0.8379, Val Accuracy: 67.72%, Val F1: 0.6694
# Epoch [10/100], Train Loss: 0.4455, Train Accuracy: 82.42%, Train F1: 0.8435, Val Loss: 0.8601, Val Accuracy: 68.30%, Val F1: 0.6711
# Epoch [11/100], Train Loss: 0.4251, Train Accuracy: 83.23%, Train F1: 0.8516, Val Loss: 0.8748, Val Accuracy: 68.30%, Val F1: 0.6714
# Epoch [12/100], Train Loss: 0.4082, Train Accuracy: 83.93%, Train F1: 0.8618, Val Loss: 0.8868, Val Accuracy: 68.16%, Val F1: 0.6702
# Epoch [13/100], Train Loss: 0.3942, Train Accuracy: 84.68%, Train F1: 0.8690, Val Loss: 0.9051, Val Accuracy: 68.59%, Val F1: 0.6739
# Epoch [14/100], Train Loss: 0.3809, Train Accuracy: 85.20%, Train F1: 0.8757, Val Loss: 0.9050, Val Accuracy: 67.72%, Val F1: 0.6690
# Epoch [15/100], Train Loss: 0.3664, Train Accuracy: 85.88%, Train F1: 0.8757, Val Loss: 0.9203, Val Accuracy: 68.30%, Val F1: 0.6753
# Epoch [16/100], Train Loss: 0.3545, Train Accuracy: 86.21%, Train F1: 0.8794, Val Loss: 0.9365, Val Accuracy: 67.72%, Val F1: 0.6710
# Epoch [17/100], Train Loss: 0.3416, Train Accuracy: 87.05%, Train F1: 0.8869, Val Loss: 0.9384, Val Accuracy: 67.72%, Val F1: 0.6692
# Epoch [18/100], Train Loss: 0.3356, Train Accuracy: 87.36%, Train F1: 0.8863, Val Loss: 0.9445, Val Accuracy: 67.72%, Val F1: 0.6657
# Epoch [19/100], Train Loss: 0.3257, Train Accuracy: 87.82%, Train F1: 0.8878, Val Loss: 0.9698, Val Accuracy: 68.01%, Val F1: 0.6701
# Epoch [20/100], Train Loss: 0.3237, Train Accuracy: 87.74%, Train F1: 0.8959, Val Loss: 0.9751, Val Accuracy: 67.29%, Val F1: 0.6645
# Epoch [21/100], Train Loss: 0.3165, Train Accuracy: 88.13%, Train F1: 0.8939, Val Loss: 0.9634, Val Accuracy: 67.72%, Val F1: 0.6684
# Epoch [22/100], Train Loss: 0.3038, Train Accuracy: 88.51%, Train F1: 0.8965, Val Loss: 0.9704, Val Accuracy: 68.88%, Val F1: 0.6751
# Epoch [23/100], Train Loss: 0.2987, Train Accuracy: 89.03%, Train F1: 0.8998, Val Loss: 0.9820, Val Accuracy: 68.59%, Val F1: 0.6818
# Epoch [24/100], Train Loss: 0.2931, Train Accuracy: 88.82%, Train F1: 0.8971, Val Loss: 1.0072, Val Accuracy: 68.44%, Val F1: 0.6738
# Epoch [25/100], Train Loss: 0.2941, Train Accuracy: 88.86%, Train F1: 0.9032, Val Loss: 0.9992, Val Accuracy: 68.30%, Val F1: 0.6724
# Epoch [26/100], Train Loss: 0.2890, Train Accuracy: 89.15%, Train F1: 0.9017, Val Loss: 1.0196, Val Accuracy: 68.01%, Val F1: 0.6698
# Epoch [27/100], Train Loss: 0.2831, Train Accuracy: 89.54%, Train F1: 0.9078, Val Loss: 1.0247, Val Accuracy: 68.01%, Val F1: 0.6708
# Epoch [28/100], Train Loss: 0.2787, Train Accuracy: 89.41%, Train F1: 0.9109, Val Loss: 1.0311, Val Accuracy: 67.29%, Val F1: 0.6661
# Epoch [29/100], Train Loss: 0.2715, Train Accuracy: 89.71%, Train F1: 0.9092, Val Loss: 1.0430, Val Accuracy: 67.58%, Val F1: 0.6633
# Epoch [30/100], Train Loss: 0.2747, Train Accuracy: 89.87%, Train F1: 0.9046, Val Loss: 1.0396, Val Accuracy: 67.44%, Val F1: 0.6654
# Epoch [31/100], Train Loss: 0.2686, Train Accuracy: 90.06%, Train F1: 0.9063, Val Loss: 1.0614, Val Accuracy: 67.44%, Val F1: 0.6625
# Epoch [32/100], Train Loss: 0.2672, Train Accuracy: 90.07%, Train F1: 0.9105, Val Loss: 1.0608, Val Accuracy: 66.71%, Val F1: 0.6603
# Epoch [33/100], Train Loss: 0.2659, Train Accuracy: 90.04%, Train F1: 0.9098, Val Loss: 1.0660, Val Accuracy: 67.29%, Val F1: 0.6654
# Epoch [34/100], Train Loss: 0.2624, Train Accuracy: 90.13%, Train F1: 0.9122, Val Loss: 1.0735, Val Accuracy: 67.87%, Val F1: 0.6683
# Epoch [35/100], Train Loss: 0.2621, Train Accuracy: 90.33%, Train F1: 0.9120, Val Loss: 1.0847, Val Accuracy: 67.72%, Val F1: 0.6635
# Epoch [36/100], Train Loss: 0.2543, Train Accuracy: 90.72%, Train F1: 0.9129, Val Loss: 1.0889, Val Accuracy: 68.73%, Val F1: 0.6751
# Epoch [37/100], Train Loss: 0.2555, Train Accuracy: 90.37%, Train F1: 0.9127, Val Loss: 1.0931, Val Accuracy: 68.16%, Val F1: 0.6689
# Epoch [38/100], Train Loss: 0.2501, Train Accuracy: 90.69%, Train F1: 0.9123, Val Loss: 1.0861, Val Accuracy: 67.44%, Val F1: 0.6647
# Epoch [39/100], Train Loss: 0.2470, Train Accuracy: 91.01%, Train F1: 0.9169, Val Loss: 1.1133, Val Accuracy: 68.01%, Val F1: 0.6709
# Epoch [40/100], Train Loss: 0.2489, Train Accuracy: 90.72%, Train F1: 0.9198, Val Loss: 1.1103, Val Accuracy: 68.30%, Val F1: 0.6747
# Epoch [41/100], Train Loss: 0.2482, Train Accuracy: 90.76%, Train F1: 0.9187, Val Loss: 1.1113, Val Accuracy: 67.29%, Val F1: 0.6643
# Epoch [42/100], Train Loss: 0.2467, Train Accuracy: 90.91%, Train F1: 0.9196, Val Loss: 1.1034, Val Accuracy: 66.71%, Val F1: 0.6552
# Epoch [43/100], Train Loss: 0.2430, Train Accuracy: 90.85%, Train F1: 0.9172, Val Loss: 1.1073, Val Accuracy: 68.73%, Val F1: 0.6790
# Epoch [44/100], Train Loss: 0.2445, Train Accuracy: 90.72%, Train F1: 0.9184, Val Loss: 1.1007, Val Accuracy: 68.44%, Val F1: 0.6754
# Epoch [45/100], Train Loss: 0.2431, Train Accuracy: 91.00%, Train F1: 0.9143, Val Loss: 1.0837, Val Accuracy: 68.59%, Val F1: 0.6760
# Epoch [46/100], Train Loss: 0.2409, Train Accuracy: 90.92%, Train F1: 0.9178, Val Loss: 1.1215, Val Accuracy: 68.01%, Val F1: 0.6711
# Epoch [47/100], Train Loss: 0.2433, Train Accuracy: 90.95%, Train F1: 0.9221, Val Loss: 1.1018, Val Accuracy: 67.72%, Val F1: 0.6695
# Epoch [48/100], Train Loss: 0.2411, Train Accuracy: 90.87%, Train F1: 0.9160, Val Loss: 1.1274, Val Accuracy: 68.16%, Val F1: 0.6734
# Epoch [49/100], Train Loss: 0.2403, Train Accuracy: 91.22%, Train F1: 0.9201, Val Loss: 1.1129, Val Accuracy: 67.87%, Val F1: 0.6675
# Epoch [50/100], Train Loss: 0.2349, Train Accuracy: 91.24%, Train F1: 0.9176, Val Loss: 1.1000, Val Accuracy: 69.02%, Val F1: 0.6837
# Epoch [51/100], Train Loss: 0.2365, Train Accuracy: 91.49%, Train F1: 0.9223, Val Loss: 1.1149, Val Accuracy: 69.02%, Val F1: 0.6805
# Epoch [52/100], Train Loss: 0.2314, Train Accuracy: 91.28%, Train F1: 0.9166, Val Loss: 1.1515, Val Accuracy: 66.71%, Val F1: 0.6559
# Epoch [53/100], Train Loss: 0.2307, Train Accuracy: 91.62%, Train F1: 0.9204, Val Loss: 1.1289, Val Accuracy: 68.30%, Val F1: 0.6734
# Epoch [54/100], Train Loss: 0.2316, Train Accuracy: 91.48%, Train F1: 0.9214, Val Loss: 1.1199, Val Accuracy: 67.15%, Val F1: 0.6624
# Epoch [55/100], Train Loss: 0.2314, Train Accuracy: 91.52%, Train F1: 0.9204, Val Loss: 1.1283, Val Accuracy: 68.73%, Val F1: 0.6769
# Epoch [56/100], Train Loss: 0.2353, Train Accuracy: 91.24%, Train F1: 0.9172, Val Loss: 1.1325, Val Accuracy: 68.73%, Val F1: 0.6744
# Epoch [57/100], Train Loss: 0.2290, Train Accuracy: 91.48%, Train F1: 0.9218, Val Loss: 1.1299, Val Accuracy: 67.87%, Val F1: 0.6702
# Epoch [58/100], Train Loss: 0.2329, Train Accuracy: 91.22%, Train F1: 0.9226, Val Loss: 1.1342, Val Accuracy: 68.44%, Val F1: 0.6769
# Epoch [59/100], Train Loss: 0.2310, Train Accuracy: 91.61%, Train F1: 0.9202, Val Loss: 1.1330, Val Accuracy: 66.71%, Val F1: 0.6596
# Epoch [60/100], Train Loss: 0.2264, Train Accuracy: 91.45%, Train F1: 0.9206, Val Loss: 1.1003, Val Accuracy: 67.58%, Val F1: 0.6683
# Epoch [61/100], Train Loss: 0.2285, Train Accuracy: 91.42%, Train F1: 0.9225, Val Loss: 1.1073, Val Accuracy: 68.44%, Val F1: 0.6762
# Epoch [62/100], Train Loss: 0.2305, Train Accuracy: 91.64%, Train F1: 0.9228, Val Loss: 1.1051, Val Accuracy: 68.44%, Val F1: 0.6755
# Epoch [63/100], Train Loss: 0.2287, Train Accuracy: 91.56%, Train F1: 0.9238, Val Loss: 1.1176, Val Accuracy: 67.44%, Val F1: 0.6645
# Epoch [64/100], Train Loss: 0.2297, Train Accuracy: 91.51%, Train F1: 0.9231, Val Loss: 1.1197, Val Accuracy: 67.44%, Val F1: 0.6656
# Epoch [65/100], Train Loss: 0.2240, Train Accuracy: 91.49%, Train F1: 0.9239, Val Loss: 1.1446, Val Accuracy: 67.87%, Val F1: 0.6714
# Epoch [66/100], Train Loss: 0.2300, Train Accuracy: 91.60%, Train F1: 0.9217, Val Loss: 1.1457, Val Accuracy: 68.30%, Val F1: 0.6695
# Epoch [67/100], Train Loss: 0.2243, Train Accuracy: 91.80%, Train F1: 0.9256, Val Loss: 1.1372, Val Accuracy: 67.58%, Val F1: 0.6705
# Epoch [68/100], Train Loss: 0.2260, Train Accuracy: 91.62%, Train F1: 0.9211, Val Loss: 1.1419, Val Accuracy: 67.15%, Val F1: 0.6637
# Epoch [69/100], Train Loss: 0.2257, Train Accuracy: 91.50%, Train F1: 0.9220, Val Loss: 1.1386, Val Accuracy: 67.72%, Val F1: 0.6679
# Epoch [70/100], Train Loss: 0.2264, Train Accuracy: 91.64%, Train F1: 0.9257, Val Loss: 1.1236, Val Accuracy: 67.15%, Val F1: 0.6613
# Epoch [71/100], Train Loss: 0.2266, Train Accuracy: 91.80%, Train F1: 0.9205, Val Loss: 1.1372, Val Accuracy: 68.59%, Val F1: 0.6721
# Epoch [72/100], Train Loss: 0.2207, Train Accuracy: 91.72%, Train F1: 0.9238, Val Loss: 1.1520, Val Accuracy: 68.30%, Val F1: 0.6701
# Epoch [73/100], Train Loss: 0.2232, Train Accuracy: 91.68%, Train F1: 0.9245, Val Loss: 1.1456, Val Accuracy: 67.58%, Val F1: 0.6692
# Epoch [74/100], Train Loss: 0.2215, Train Accuracy: 91.86%, Train F1: 0.9258, Val Loss: 1.1363, Val Accuracy: 67.44%, Val F1: 0.6661
# Epoch [75/100], Train Loss: 0.2185, Train Accuracy: 91.91%, Train F1: 0.9238, Val Loss: 1.1405, Val Accuracy: 67.44%, Val F1: 0.6612
# Epoch [76/100], Train Loss: 0.2226, Train Accuracy: 91.86%, Train F1: 0.9242, Val Loss: 1.1505, Val Accuracy: 67.29%, Val F1: 0.6612
# Epoch [77/100], Train Loss: 0.2188, Train Accuracy: 91.78%, Train F1: 0.9257, Val Loss: 1.1658, Val Accuracy: 67.00%, Val F1: 0.6603
# Epoch [78/100], Train Loss: 0.2186, Train Accuracy: 92.17%, Train F1: 0.9274, Val Loss: 1.1575, Val Accuracy: 68.16%, Val F1: 0.6746
# Epoch [79/100], Train Loss: 0.2172, Train Accuracy: 91.97%, Train F1: 0.9228, Val Loss: 1.1566, Val Accuracy: 66.86%, Val F1: 0.6571
# Epoch [80/100], Train Loss: 0.2171, Train Accuracy: 92.02%, Train F1: 0.9234, Val Loss: 1.1704, Val Accuracy: 68.30%, Val F1: 0.6702
# Epoch [81/100], Train Loss: 0.2192, Train Accuracy: 92.09%, Train F1: 0.9233, Val Loss: 1.1312, Val Accuracy: 68.01%, Val F1: 0.6682
# Epoch [82/100], Train Loss: 0.2201, Train Accuracy: 91.94%, Train F1: 0.9243, Val Loss: 1.1110, Val Accuracy: 67.87%, Val F1: 0.6690
# Epoch [83/100], Train Loss: 0.2207, Train Accuracy: 92.00%, Train F1: 0.9276, Val Loss: 1.1074, Val Accuracy: 67.58%, Val F1: 0.6645
# Epoch [84/100], Train Loss: 0.2217, Train Accuracy: 91.90%, Train F1: 0.9264, Val Loss: 1.1015, Val Accuracy: 68.30%, Val F1: 0.6717
# Epoch [85/100], Train Loss: 0.2240, Train Accuracy: 91.84%, Train F1: 0.9260, Val Loss: 1.1368, Val Accuracy: 67.15%, Val F1: 0.6601
# Epoch [86/100], Train Loss: 0.2190, Train Accuracy: 91.86%, Train F1: 0.9248, Val Loss: 1.1333, Val Accuracy: 67.72%, Val F1: 0.6656
# Epoch [87/100], Train Loss: 0.2211, Train Accuracy: 91.89%, Train F1: 0.9240, Val Loss: 1.1631, Val Accuracy: 68.01%, Val F1: 0.6658
# Epoch [88/100], Train Loss: 0.2175, Train Accuracy: 91.87%, Train F1: 0.9260, Val Loss: 1.1443, Val Accuracy: 68.30%, Val F1: 0.6710
# Epoch [89/100], Train Loss: 0.2160, Train Accuracy: 92.02%, Train F1: 0.9249, Val Loss: 1.1410, Val Accuracy: 68.01%, Val F1: 0.6674
# Epoch [90/100], Train Loss: 0.2191, Train Accuracy: 91.87%, Train F1: 0.9262, Val Loss: 1.1495, Val Accuracy: 66.43%, Val F1: 0.6543
# Epoch [91/100], Train Loss: 0.2198, Train Accuracy: 91.88%, Train F1: 0.9247, Val Loss: 1.1429, Val Accuracy: 67.72%, Val F1: 0.6654
# Epoch [92/100], Train Loss: 0.2203, Train Accuracy: 91.50%, Train F1: 0.9233, Val Loss: 1.1459, Val Accuracy: 67.00%, Val F1: 0.6599
# Epoch [93/100], Train Loss: 0.2159, Train Accuracy: 92.05%, Train F1: 0.9251, Val Loss: 1.1524, Val Accuracy: 67.00%, Val F1: 0.6603
# Epoch [94/100], Train Loss: 0.2234, Train Accuracy: 91.52%, Train F1: 0.9240, Val Loss: 1.1496, Val Accuracy: 66.86%, Val F1: 0.6590
# Epoch [95/100], Train Loss: 0.2185, Train Accuracy: 91.97%, Train F1: 0.9277, Val Loss: 1.1314, Val Accuracy: 67.29%, Val F1: 0.6671
# Epoch [96/100], Train Loss: 0.2179, Train Accuracy: 92.00%, Train F1: 0.9264, Val Loss: 1.1263, Val Accuracy: 67.44%, Val F1: 0.6603
# Epoch [97/100], Train Loss: 0.2154, Train Accuracy: 91.98%, Train F1: 0.9229, Val Loss: 1.1520, Val Accuracy: 67.44%, Val F1: 0.6661
# Epoch [98/100], Train Loss: 0.2138, Train Accuracy: 91.93%, Train F1: 0.9255, Val Loss: 1.1460, Val Accuracy: 67.58%, Val F1: 0.6685
# Epoch [99/100], Train Loss: 0.2215, Train Accuracy: 91.37%, Train F1: 0.9267, Val Loss: 1.1244, Val Accuracy: 66.43%, Val F1: 0.6525
# Epoch [100/100], Train Loss: 0.2161, Train Accuracy: 91.94%, Train F1: 0.9257, Val Loss: 1.1309, Val Accuracy: 67.00%, Val F1: 0.6575
# Test Loss: 24.8806, Test Accuracy: 67.00%, Test F1: 0.6575

# %%
plt.figure()
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(train_f1_scores, label='Train F1-score')
plt.plot(val_f1_scores, label='Validation F1-score')
plt.xlabel('Epochs')
plt.ylabel('F1-score')
plt.legend()
plt.show()
